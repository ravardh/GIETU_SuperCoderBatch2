# %% [markdown]
# ## KMP Pattern Search

# %%
#KMP Algorithm

def KMPSearch(pat, data):
    M = len(pat)
    N = len(data)
    
    lps = [0]*M
    j = 0 
    
    LPS(pat, M, lps)

    i = 0 
    while (N - i) >= (M - j):
        if pat[j] == data[i]:
            i += 1
            j += 1

        if j == M:
            print("Found pattern at index " + str(i-j))
            j = lps[j-1]

        elif i < N and pat[j] != data[i]:
            if j != 0:
                j = lps[j-1]
            else:
                i += 1


def LPS(pat, M, lps):
    len = 0 

    lps[0] = 0 
    i = 1

    
    while i < M:
        if pat[i] == pat[len]:
            len += 1
            lps[i] = len
            i += 1
        else:
            if len != 0:
                len = lps[len-1]
            else:
                lps[i] = 0
                i += 1


# Driver code
if __name__ == '__main__':
    data = "ABAABABCABABABCAABABCABAC"
    pat = "ABABC"
    KMPSearch(pat, data)
# Out:
# Found pattern at index 3
# Found pattern at index 10
# Found pattern at index 16

# %% [markdown]
# ## Linked List

# %%
class node:
    def __init__(self,data=None):
        self.data=data
        self.next=None
newNode = node(1)
start = newNode

start.next= node(2)
start.next.next= node(3)
start.next.next.next= node(4)
start.next.next.next.next= node(5)

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)


n1=node(0)
n1.next=start
start=n1
print("Node added into begining")

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)



n2=node(6)
temp=start
while temp.next:
    temp=temp.next
temp.next=n2
print("Node added into End")

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)
# Out:
# <__main__.node object at 0x0000026B830A8340>
# 1
# <__main__.node object at 0x0000026B830A8B50>
# 2
# <__main__.node object at 0x0000026B830A81C0>
# 3
# <__main__.node object at 0x0000026B830A82B0>
# 4
# <__main__.node object at 0x0000026B830A8370>
# 5
# None
# Node added into begining
# <__main__.node object at 0x0000026B830A8EE0>
# 0
# <__main__.node object at 0x0000026B830A8340>
# 1
# <__main__.node object at 0x0000026B830A8B50>
# 2
# <__main__.node object at 0x0000026B830A81C0>
# 3
# <__main__.node object at 0x0000026B830A82B0>
# 4
# <__main__.node object at 0x0000026B830A8370>
# 5
# None
# Node added into End
# <__main__.node object at 0x0000026B830A8EE0>
# 0
# <__main__.node object at 0x0000026B830A8340>
# 1
# <__main__.node object at 0x0000026B830A8B50>
# 2
# <__main__.node object at 0x0000026B830A81C0>
# 3
# <__main__.node object at 0x0000026B830A82B0>
# 4
# <__main__.node object at 0x0000026B830A8370>
# 5
# <__main__.node object at 0x0000026B830A8820>
# 6
# None

# %% [markdown]
# ## Recursion

# %%
class node:
    def __init__(self,data=None):
        self.data=data
        self.next=None
newNode = node(1)
start = newNode

start.next= node(2)
start.next.next= node(3)
start.next.next.next= node(4)
start.next.next.next.next= node(5)

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)


n1=node(0)
n1.next=start
start=n1
print("Node added into begining")

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)



n2=node(6)
temp=start
while temp.next:
    temp=temp.next
temp.next=n2
print("Node added into End")

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)
# Out:
# <__main__.node object at 0x0000026B830CD460>
# 1
# <__main__.node object at 0x0000026B830CDBE0>
# 2
# <__main__.node object at 0x0000026B830CDFD0>
# 3
# <__main__.node object at 0x0000026B830CD760>
# 4
# <__main__.node object at 0x0000026B830CD1F0>
# 5
# None
# Node added into begining
# <__main__.node object at 0x0000026B830CD6A0>
# 0
# <__main__.node object at 0x0000026B830CD460>
# 1
# <__main__.node object at 0x0000026B830CDBE0>
# 2
# <__main__.node object at 0x0000026B830CDFD0>
# 3
# <__main__.node object at 0x0000026B830CD760>
# 4
# <__main__.node object at 0x0000026B830CD1F0>
# 5
# None
# Node added into End
# <__main__.node object at 0x0000026B830CD6A0>
# 0
# <__main__.node object at 0x0000026B830CD460>
# 1
# <__main__.node object at 0x0000026B830CDBE0>
# 2
# <__main__.node object at 0x0000026B830CDFD0>
# 3
# <__main__.node object at 0x0000026B830CD760>
# 4
# <__main__.node object at 0x0000026B830CD1F0>
# 5
# <__main__.node object at 0x0000026B830CD580>
# 6
# None

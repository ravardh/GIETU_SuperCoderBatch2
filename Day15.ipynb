# %%
#Cycle Detection
class Edge:
    def __init__(self,s,d,w):
        self.source=s
        self.destination=d
        self.weight=w
class GraphLevelOrder:
    def __init__(self):
            self.l = []
    def insertv(self):
        for i in range(3):
            self.l.append([])
        # self.l[0].append(Edge(1,2,4))
        # self.l[0].append(Edge(1,8,8))

        # self.l[1].append(Edge(2,3,8))
        # self.l[1].append(Edge(2,8,11))
        # self.l[1].append(Edge(2,1,4))


        # self.l[2].append(Edge(3,2,8))
        # self.l[2].append(Edge(3,9,2))
        # self.l[2].append(Edge(3,6,4))
        # self.l[2].append(Edge(3,4,7))

        # self.l[3].append(Edge(4,3,7))
        # self.l[3].append(Edge(4,6,14))
        # self.l[3].append(Edge(4,5,9))

        # self.l[4].append(Edge(5,4,9))
        # self.l[4].append(Edge(5,6,10))

        # self.l[5].append(Edge(6,5,10))
        # self.l[5].append(Edge(6,4,14))
        # self.l[5].append(Edge(6,3,4))
        # self.l[5].append(Edge(6,7,2))


        # self.l[6].append(Edge(7,6,2))
        # self.l[6].append(Edge(7,9,6))
        # self.l[6].append(Edge(7,8,1))

        # self.l[7].append(Edge(8,1,8))
        # self.l[7].append(Edge(8,2,11))
        # self.l[7].append(Edge(8,9,7))
        # self.l[7].append(Edge(8,7,1))

        self.l[0].append(Edge(1,2,2))
        self.l[0].append(Edge(1,3,7))

        self.l[1].append(Edge(2,1,2))
        self.l[1].append(Edge(2,3,7))

        self.l[2].append(Edge(3,1,2))
        self.l[2].append(Edge(3,2,7))
    def display(self):
        for i in self.l:
            for j in i:
                print("( ", j.source, " , ", j.destination, " )", end="\t")
            print()
    def findShortestPath(self,start):
      dist = dict()
      for x in range(1,len(self.l)+1):
        dist[x]=float('inf')
      dist[start]=0
      Visit=[]
      while len(dist) != 0:
        found_key = next((key for key, value in dist.items() if value == min(dist.values())), None)
        for i in range(len(self.l[found_key-1])):
          if(self.l[found_key-1][i].destination in dist.keys()):
            dist[self.l[found_key-1][i].destination] = min(dist[self.l[found_key-1][i].destination], dist[found_key] + self.l[found_key-1][i].weight)
        Visit.append([found_key,dist[found_key]])
        del dist[found_key]
      return Visit

    def cycleTest(self,start,child,ind):
      for i in range(ind,len(self.l[start-1])):
          child=self.l[start-1][i].destination
          for j in range(len(self.l[child-1])):
              if(start==self.l[child-1][j].destination):
                  return True
      return False
g=GraphLevelOrder()
g.insertv()
g.display()
start=1
child=None
ind=0
# visit=[False,False,False]
print(g.cycleTest(1,child,ind))
# Out:
# (  1  ,  2  )	(  1  ,  3  )
# (  2  ,  1  )	(  2  ,  3  )
# (  3  ,  1  )	(  3  ,  2  )
# True

# %%
#Prims Algorithm
class Edge:
    def __init__(self,s,d,w):
        self.source=s
        self.destination=d
        self.weight=w
class GraphLevelOrder:
    def __init__(self):
            self.l = []
    def insertv(self):
        for i in range(3):
            self.l.append([])
        # self.l[0].append(Edge(1,2,4))
        # self.l[0].append(Edge(1,8,8))

        # self.l[1].append(Edge(2,3,8))
        # self.l[1].append(Edge(2,8,11))
        # self.l[1].append(Edge(2,1,4))


        # self.l[2].append(Edge(3,2,8))
        # self.l[2].append(Edge(3,9,2))
        # self.l[2].append(Edge(3,6,4))
        # self.l[2].append(Edge(3,4,7))

        # self.l[3].append(Edge(4,3,7))
        # self.l[3].append(Edge(4,6,14))
        # self.l[3].append(Edge(4,5,9))

        # self.l[4].append(Edge(5,4,9))
        # self.l[4].append(Edge(5,6,10))

        # self.l[5].append(Edge(6,5,10))
        # self.l[5].append(Edge(6,4,14))
        # self.l[5].append(Edge(6,3,4))
        # self.l[5].append(Edge(6,7,2))


        # self.l[6].append(Edge(7,6,2))
        # self.l[6].append(Edge(7,9,6))
        # self.l[6].append(Edge(7,8,1))

        # self.l[7].append(Edge(8,1,8))
        # self.l[7].append(Edge(8,2,11))
        # self.l[7].append(Edge(8,9,7))
        # self.l[7].append(Edge(8,7,1))

        self.l[0].append(Edge(1,2,2))
        self.l[0].append(Edge(1,3,7))

        self.l[1].append(Edge(2,1,1))
        self.l[1].append(Edge(2,3,5))

        self.l[2].append(Edge(3,1,3))
        self.l[2].append(Edge(3,2,4))
    def display(self):
        for i in self.l:
            for j in i:
                print("( ", j.source, " , ", j.destination, " )", end="\t")
            print()
    def cycleTest(self,start,child,ind):
      for i in range(ind,len(self.l[start-1])):
          child=self.l[start-1][i].destination
          for j in range(len(self.l[child-1])):
              if(start==self.l[child-1][j].destination):
                  return True
      return False
    def maxEdge(self,List):
      weight=[]
      for i in List:
          for j in i:
            weight.append(j.weight)
      weight.sort(reverse=True)
      return weight[0]
    def maxInVertex(self,vertex,listg):
      weight=[]
      for j in list[vertex-1]:
          weight.append(j.weight)
      weight.sort(reverse=True)
      return weight[0]
    def prims(self):
      spining=[]
      for i in range(3):
            self.l.append([])
      edge=self.maxEdge(self.l)
      print(edge)
      for i in self.l:
          for j in i:
            if(j.weight==edge):
                spining[j.source-1].append(Edge(j.source,j.destination,j.weight))
                print(self.maxInVertex(self.l,j.source))
g=GraphLevelOrder()
g.insertv()
g.display()
start=1
child=None
ind=0
print(g.cycleTest(1,child,ind))
g.prims()
# Out:
# (  1  ,  2  )	(  1  ,  3  )
# (  2  ,  1  )	(  2  ,  3  )
# (  3  ,  1  )	(  3  ,  2  )
# True
# 7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-33dd6b897f75> in <cell line: 99>()
#      97 ind=0
#      98 print(g.cycleTest(1,child,ind))
# ---> 99 g.prims()
#
# <ipython-input-5-33dd6b897f75> in prims(self)
#      88           for j in i:
#      89             if(j.weight==edge):
# ---> 90                 spining[j.source-1].append(Edge(j.source,j.destination,j.weight))
#      91                 print(self.maxInVertex(self.l,j.source))
#      92 g=GraphLevelOrder()
#
# IndexError: list index out of range

# %%
#Kruskal Algorithm
class Edge:
    def __init__(self,s,d,w):
        self.source=s
        self.destination=d
        self.weight=w
class GraphLevelOrder:
    def __init__(self):
            self.l = []
    def insertv(self):
        for i in range(5):
            self.l.append([])

        self.l[0].append(Edge(1,2,1))
        self.l[0].append(Edge(1,3,2))

        self.l[1].append(Edge(2,4,8))
        self.l[1].append(Edge(2,3,3))

        self.l[2].append(Edge(3,1,2))
        self.l[2].append(Edge(3,2,3))
        self.l[2].append(Edge(3,5,4))

        self.l[3].append(Edge(4,2,8))
        self.l[3].append(Edge(4,5,6))

        self.l[4].append(Edge(5,4,6))
        self.l[4].append(Edge(5,3,4))
    def display(self):
        for i in self.l:
            for j in i:
                print("( ", j.source, " , ", j.destination, " )", end="\t")
            print()

    def cycleTest(self,l,start,child):
      for i in range(len(l[start-1])):
          child=l[start-1][i].destination
          for j in range(len(l[child-1])):
              if(start==l[child-1][j].destination):
                  return True
      return False


    def Kruskal(self):
      # self.l.sort()
      spining=[]
      for i in range(5):
            spining.append([])
      weight=[]
      for i in self.l:
          for j in i:
            weight.append(j.weight)
      weight.sort()
      weight.reverse()
      # print(weight)
      for k in weight:
        for i in self.l:
          for j in i:
            if(j.weight==k):
              spining[j.source-1].append(Edge(j.source,j.destination,j.weight))
              # print(j.source,j.destination,j.weight)
              # print(self.cycleTest(spining,1,None))
            if(self.cycleTest(spining,1,None)):
              del spining[j.source-1][-1]
              for i in spining:
                for j in i:
                  print("( ", j.source, " , ", j.destination, " )", end="\t")
              break
            else:
              break

      for i in spining:
            for j in i:
                print("( ", j.source, " , ", j.destination, " )", end="\t")
            print()


g=GraphLevelOrder()
g.insertv()
# g.display()
start=1
child=None
ind=0
# print(g.cycleTest(1,child))
g.Kruskal()
# Out:
# (  1  ,  2  )
# (  2  ,  4  )	(  2  ,  4  )
# (  3  ,  1  )	(  3  ,  1  )
# (  4  ,  2  )	(  4  ,  2  )
# (  5  ,  4  )	(  5  ,  4  )

# %%
#Job Scheduling
l=[[25,4],[20,2],[30,4],[15,3],[5,2],[35,3],[12,1]]
l.sort()
l.reverse()
# print(l)
l1=[-1,-1,-1,-1]
for i in range(len(l)):
  for j in range(l[i][1]-1,-1,-1):
    if(l1[j]==-1):
      l1[j]=l[i][0]
      break
print(sum(l1))
# Out:
# 110

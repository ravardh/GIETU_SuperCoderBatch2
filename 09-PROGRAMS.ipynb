# %%
def AdjacencyList():
    A_L=[]

    n=int(input("enter the  number of vertex:-"))
    for i in range(1,n+1):
        list = []
        print(f"how many connections have for{i}:-")
        con=int(input())
        print(f"entre the connction of {i}by space \n")
        for j in range(0, con):
            b=int(input("dest:-"))
            list.append(tuple((i,b)))
        A_L.append(list)
    for i in A_L:
        j=1
        print(f"for {j}th node:-")
        j+=1
        print(i)
        #j+=1
    print(A_L)
AdjacencyList()
# Out:
# enter the  number of vertex:-5
# how many connections have for1:-
# 2
# entre the connction of 1by space
#
# dest:-3
# dest:-2
# how many connections have for2:-
# 2
# entre the connction of 2by space
#
# dest:-4
# dest:-1
# how many connections have for3:-
# 2
# entre the connction of 3by space
#
# dest:-9
# dest:-1
# how many connections have for4:-
# 2
# entre the connction of 4by space
#
# dest:-6
# dest:-2
# how many connections have for5:-
# 5
# entre the connction of 5by space
#
# dest:-4
# dest:-1
# dest:-9
# dest:-8
# dest:-7
# for 1th node:-
# [(1, 3), (1, 2)]
# for 1th node:-
# [(2, 4), (2, 1)]
# for 1th node:-
# [(3, 9), (3, 1)]
# for 1th node:-
# [(4, 6), (4, 2)]
# for 1th node:-
# [(5, 4), (5, 1), (5, 9), (5, 8), (5, 7)]
# [[(1, 3), (1, 2)], [(2, 4), (2, 1)], [(3, 9), (3, 1)], [(4, 6), (4, 2)], [(5, 4), (5, 1), (5, 9), (5, 8), (5, 7)]]

# %%
def AdjacencyMatrix():
    l1=[]
    n=int(input("enter the  number of vertex:-"))
    for i in range(1,n+1):
        list = [0]*(n+1)
        print(f"how many connections have for{i}:-")
        con=int(input())
        print(f"entre the connction of {i}by space \n")
        for j in range(0, con):
            b=int(input("dest:-"))
            list[b]=1
        l1.append(list)
    for i in l1:
        print("\n",i)
AdjacencyMatrix()

# %%
def AdjacencyMatrix():
    l1=[]
    n=int(input("enter the  number of vertex:-"))
    for i in range(1,n+1):
        list = [-1]*(n+1)
        list[i]=0
        print(f"how many connections have for{i}:-")
        con=int(input())
        print(f"entre the connction of {i}by space \n")
        for j in range(0, con):
            b=int(input("dest:-"))
            if(b==i):
                print("Source destination can't be same")
                exit()
            else:
                list[b]=int(input("enter the weight"))
        l1.append(list)
    for i in l1:
        print("\n",i)
AdjacencyMatrix()

# %% [markdown]
# # KMP Algorithm

# %%
#KMP Algorithm


def KMPSearch(pat, data):
    M = len(pat)
    N = len(data)
    lps = [0]*M
    j = 0 
    LPS(pat, M, lps)

    i = 0 
    while (N - i) >= (M - j):
        if pat[j] == data[i]:
            i += 1
            j += 1

        if j == M:
            print("Found pattern at index " + str(i-j))
            j = lps[j-1]

        elif i < N and pat[j] != data[i]:
            if j != 0:
                j = lps[j-1]
            else:
                i += 1



def LPS(pat, M, lps):
    len = 0 

    lps[0] = 0 
    i = 1


    while i < M:
        if pat[i] == pat[len]:
            len += 1
            lps[i] = len
            i += 1
        else:
            if len != 0:
                len = lps[len-1]
            else:
                lps[i] = 0
                i += 1


# Driver code
data = "ABAABABCABABABCAABABCABAC"
pat = "ABABC"
KMPSearch(pat, data)
# Out:
# Found pattern at index 3
# Found pattern at index 10
# Found pattern at index 16

# %% [markdown]
# # Linked list

# %%
# Python program to implement 
# a Singly Linked List 

class Node: 
    def __init__(self, data): 
        self.data = data 
        self.next = None

class LinkedList: 
    def __init__(self): 
        self.head = None

    # Method to insert a new node 
    def insert(self, data): 
        # Create a new node with given data 
        new_node = Node(data)

        # If the Linked List is empty, 
        # then make the new node as head 
        if self.head is None: 
            self.head = new_node 
            return

        # Else traverse till the last node 
        # and insert the new_node there 
        last = self.head 
        while last.next: 
            last = last.next

        # Insert the new_node at last node 
        last.next = new_node 

    # Method to print the LinkedList 
    def printList(self): 
        currNode = self.head 
        print("LinkedList:", end=" ") 
        while currNode: 
            # Print the data at current node 
            print(currNode.data, end=" ") 
            # Go to next node 
            currNode = currNode.next
        print() 

# Driver code 
if __name__ == '__main__': 
    # Start with the empty list 
    list = LinkedList() 

    # Insert the values 
    list.insert(1) 
    list.insert(2) 
    list.insert(3) 
    list.insert(4) 
    list.insert(5) 
    list.insert(6) 
    list.insert(7) 
    list.insert(8) 

    # Print the LinkedList 
    list.printList()
# Out:
# LinkedList: 1 2 3 4 5 6 7 8

# %%
#LINK LIST

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
newNode=node(1)
start=newNode
start.next=node(2)
start.next.next=node(3)
start.next.next.next=node(4)
start.next.next.next.next=node(5)

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)


n1=node(0)
n1.next=start
start=n1
print("Node added into begining")

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)



n2=node(6)
temp=start
while temp.next:
    temp=temp.next
temp.next=n2
print("Node added into End")

temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)
# Out:
# <__main__.node object at 0x0000025CD4AD16D0>
# 1
# <__main__.node object at 0x0000025CD4AD0250>
# 2
# <__main__.node object at 0x0000025CD4A77010>
# 3
# <__main__.node object at 0x0000025CD4A76910>
# 4
# <__main__.node object at 0x0000025CD4A750D0>
# 5
# None
# Node added into begining
# <__main__.node object at 0x0000025CD4A76350>
# 0
# <__main__.node object at 0x0000025CD4AD16D0>
# 1
# <__main__.node object at 0x0000025CD4AD0250>
# 2
# <__main__.node object at 0x0000025CD4A77010>
# 3
# <__main__.node object at 0x0000025CD4A76910>
# 4
# <__main__.node object at 0x0000025CD4A750D0>
# 5
# None
# Node added into End
# <__main__.node object at 0x0000025CD4A76350>
# 0
# <__main__.node object at 0x0000025CD4AD16D0>
# 1
# <__main__.node object at 0x0000025CD4AD0250>
# 2
# <__main__.node object at 0x0000025CD4A77010>
# 3
# <__main__.node object at 0x0000025CD4A76910>
# 4
# <__main__.node object at 0x0000025CD4A750D0>
# 5
# <__main__.node object at 0x0000025CD49DDA10>
# 6
# None

# %% [markdown]
# # Deleting a node

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
newNode=node(1)
start=newNode
start.next=node(2)
start.next.next=node(3)
start.next.next.next=node(4)
start.next.next.next.next=node(5)


print(type(start.data))

print("Before Deletion: ")
temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)


a=int(input("Enter element to delete: "))
temp=start
while temp.next:
    if temp.next.data==a:
        temp.next=temp.next.next
    temp=temp.next
        
print("After Deletion: ")
temp = start
print(temp)
while temp:
    print(temp.data)
    temp=temp.next
    print(temp)
# Out:
# <class 'int'>
# Before Deletion:
# <__main__.node object at 0x000002D86A1CA410>
# 1
# <__main__.node object at 0x000002D86A0F3550>
# 2
# <__main__.node object at 0x000002D86A146090>
# 3
# <__main__.node object at 0x000002D86A145ED0>
# 4
# <__main__.node object at 0x000002D86A10EE90>
# 5
# None
# Enter element to delete: 2
# After Deletion:
# <__main__.node object at 0x000002D86A1CA410>
# 1
# <__main__.node object at 0x000002D86A146090>
# 3
# <__main__.node object at 0x000002D86A145ED0>
# 4
# <__main__.node object at 0x000002D86A10EE90>
# 5
# None
